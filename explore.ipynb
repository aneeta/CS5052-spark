# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(
    "data/pupil-absence-in-schools-in-england_2018-19/data/Absence_3term201819_nat_reg_la_sch.csv"
)
# Out:
# /tmp/ipykernel_28977/2746722265.py:1: DtypeWarning: Columns (13,15,16,17,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(

# %%
data.school_type.unique()
# Out:
# array(['Total', 'State-funded primary', 'State-funded secondary',
#        'Special'], dtype=object)

# %%
data.academy_type.unique()
# Out:
# array([nan, 'Primary free school', 'Primary sponsor led academy',
#        'Secondary sponsor led academy', 'Primary converter academy',
#        'Secondary free school', 'Secondary converter academy',
#        'Special converter academy', 'Special free school',
#        'Secondary UTC', 'Special sponsor led academy',
#        'Secondary studio school'], dtype=object)

# %%
data.urn.unique()
# Out:
# array([nan, 100000.0, 136807.0, ..., 126077, 126078, 126091], dtype=object)

# %%
data.estab.unique()
# Out:
# array([  nan, 3614., 2000., ..., 4577., 4582., 4720.])

# %%
data[(~data.estab.isna()) | (~data.laestab.isna())].loc[:, "estab":"sess_possible_pa_10_exact"]
# Out:
#          estab    laestab       urn           school_type  \
# 647     3614.0  2013614.0  100000.0  State-funded primary
# 648     2000.0  2022000.0  136807.0  State-funded primary
# 649     2001.0  2022001.0  139837.0  State-funded primary
# 650     2002.0  2022002.0  140686.0  State-funded primary
# 651     2019.0  2022019.0  100008.0  State-funded primary
# ...        ...        ...       ...                   ...
# 285258  7012.0  9387012.0    126163               Special
# 285259  7015.0  9387015.0    126164               Special
# 285260  7016.0  9387016.0    126165               Special
# 285261  7021.0  9387021.0    126169               Special
# 285262  7022.0  9387022.0    126170               Special
#
#                        academy_type academy_open_date all_through  \
# 647                             NaN               NaN         NaN
# 648             Primary free school        12/09/2011         NaN
# 649             Primary free school        01/09/2013         NaN
# ...

# %%
data[(data.year_breakdown == 'five half terms')].max()
# Out:
# /tmp/ipykernel_2648929/2936029595.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data[(data.year_breakdown == 'five half terms')].max()
# time_identifier                            Academic year
# year_breakdown                           five half terms
# time_period                                       201112
# geographic_level                                  School
# country_code                                   E92000001
# country_name                                     England
# old_la_code                                        938.0
# estab                                             7750.0
# laestab                                        9387023.0
# school_type                                        Total
# ...

# %%
data[data.geographic_level == 'National']
# Out:
#        time_identifier   year_breakdown  time_period geographic_level  \
# 0        Academic year   six half terms       201819         National
# 1        Academic year   six half terms       201819         National
# 2        Academic year   six half terms       201819         National
# 3        Academic year   six half terms       201819         National
# 21861    Academic year   six half terms       201718         National
# 21862    Academic year   six half terms       201718         National
# 21863    Academic year   six half terms       201718         National
# 21864    Academic year   six half terms       201718         National
# 43770    Academic year   six half terms       201617         National
# 43771    Academic year   six half terms       201617         National
# 43772    Academic year   six half terms       201617         National
# 43773    Academic year   six half terms       201617         National
# ...

# %%
data[data['la_name'].isna() & (data.time_period == 201819) & (data.region_name.isna())]
# Out:
#   time_identifier  year_breakdown  time_period geographic_level country_code  \
# 0   Academic year  six half terms       201819         National    E92000001
# 1   Academic year  six half terms       201819         National    E92000001
# 2   Academic year  six half terms       201819         National    E92000001
# 3   Academic year  six half terms       201819         National    E92000001
#
#   country_name region_code region_name  old_la_code new_la_code  ...  \
# 0      England         NaN         NaN          NaN         NaN  ...
# 1      England         NaN         NaN          NaN         NaN  ...
# 2      England         NaN         NaN          NaN         NaN  ...
# 3      England         NaN         NaN          NaN         NaN  ...
#
#   sess_auth_ext_holiday  sess_auth_excluded  sess_auth_other  \
# 0                     :             2049972          7588162
# 1                     :              297184          3129669
# ...

# %%
data[data.new_la_code == '.']
# Out:
#        time_identifier   year_breakdown  time_period geographic_level  \
# 240923   Academic year  five half terms       200708  Local authority
# 240924   Academic year  five half terms       200708  Local authority
# 240925   Academic year  five half terms       200708  Local authority
# 240926   Academic year  five half terms       200708  Local authority
# 241047   Academic year  five half terms       200708  Local authority
# ...                ...              ...          ...              ...
# 276766   Academic year  five half terms       200607           School
# 276767   Academic year  five half terms       200607           School
# 276768   Academic year  five half terms       200607           School
# 276769   Academic year  five half terms       200607           School
# 276770   Academic year  five half terms       200607           School
#
#        country_code country_name region_code      region_name  old_la_code  \
# ...

# %%
data.groupby(['new_la_code', 'la_name']).min()
# Out:
# /tmp/ipykernel_1869868/2755803574.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   data.groupby(['new_la_code', 'la_name']).min()
#                                         time_identifier   year_breakdown  \
# new_la_code la_name
# .           Bedfordshire (Pre LGR 2009)   Academic year  five half terms
#             Cheshire (Pre LGR 2009)       Academic year  five half terms
# E06000001   Hartlepool                    Academic year  five half terms
# E06000002   Middlesbrough                 Academic year  five half terms
# E06000003   Redcar and Cleveland          Academic year  five half terms
# ...                                                 ...              ...
# E10000029   Suffolk                       Academic year  five half terms
# ...

# %%
data.geographic_level.unique()
# Out:
# array(['National', 'Regional', 'Local authority', 'School'], dtype=object)

# %%
data[data.geographic_level == 'School'][['estab','laestab','urn', 'num_schools']]
# Out:
#          estab    laestab       urn  num_schools
# 647     3614.0  2013614.0  100000.0            1
# 648     2000.0  2022000.0  136807.0            1
# 649     2001.0  2022001.0  139837.0            1
# 650     2002.0  2022002.0  140686.0            1
# 651     2019.0  2022019.0  100008.0            1
# ...        ...        ...       ...          ...
# 285258  7012.0  9387012.0    126163            1
# 285259  7015.0  9387015.0    126164            1
# 285260  7016.0  9387016.0    126165            1
# 285261  7021.0  9387021.0    126169            1
# 285262  7022.0  9387022.0    126170            1
#
# [276863 rows x 4 columns]

# %%
data.columns
# Out:
# Index(['time_identifier', 'year_breakdown', 'time_period', 'geographic_level',
#        'country_code', 'country_name', 'region_code', 'region_name',
#        'old_la_code', 'new_la_code', 'la_name', 'estab', 'laestab', 'urn',
#        'school_type', 'academy_type', 'academy_open_date', 'all_through',
#        'num_schools', 'enrolments', 'sess_possible', 'sess_overall',
#        'sess_authorised', 'sess_unauthorised', 'sess_overall_percent',
#        'sess_authorised_percent', 'sess_unauthorised_percent',
#        'enrolments_pa_10_exact', 'enrolments_pa_10_exact_percent',
#        'sess_possible_pa_10_exact', 'sess_overall_pa_10_exact',
#        'sess_authorised_pa_10_exact', 'sess_unauthorised_pa_10_exact',
#        'sess_overall_percent_pa_10_exact',
#        'sess_authorised_percent_pa_10_exact',
#        'sess_unauthorised_percent_pa_10_exact', 'sess_auth_illness',
#        'sess_auth_appointments', 'sess_auth_religious', 'sess_auth_study',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285263 entries, 0 to 285262
# Data columns (total 52 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   time_identifier                        285263 non-null  object
#  1   year_breakdown                         285263 non-null  object
#  2   time_period                            285263 non-null  int64
#  3   geographic_level                       285263 non-null  object
#  4   country_code                           285263 non-null  object
#  5   country_name                           285263 non-null  object
#  6   region_code                            285211 non-null  object
#  7   region_name                            285211 non-null  object
#  8   old_la_code                            284691 non-null  float64
#  9   new_la_code                            284691 non-null  object
# ...

# %%
data.loc[:, ['time_identifier', 'year_breakdown', 'time_period', 'geographic_level',
       'country_code', 'country_name', 'region_code', 'region_name',
       'old_la_code', 'new_la_code', 'la_name', 'estab', 'laestab', 'urn',
       'school_type', 'academy_type', 'academy_open_date', 'all_through',
       'num_schools', 'enrolments']]
# Out:
#        time_identifier   year_breakdown  time_period geographic_level  \
# 0        Academic year   six half terms       201819         National
# 1        Academic year   six half terms       201819         National
# 2        Academic year   six half terms       201819         National
# 3        Academic year   six half terms       201819         National
# 4        Academic year   six half terms       201819         Regional
# ...                ...              ...          ...              ...
# 285258   Academic year  five half terms       200607           School
# 285259   Academic year  five half terms       200607           School
# 285260   Academic year  five half terms       200607           School
# 285261   Academic year  five half terms       200607           School
# 285262   Academic year  five half terms       200607           School
#
#        country_code country_name region_code region_name  old_la_code  \
# ...

# %%
data.iloc[285262]
# Out:
# time_identifier                            Academic year
# year_breakdown                           five half terms
# time_period                                       200607
# geographic_level                                  School
# country_code                                   E92000001
# country_name                                     England
# region_code                                    E12000008
# region_name                                   South East
# old_la_code                                        938.0
# new_la_code                                    E10000032
# la_name                                      West Sussex
# estab                                             7022.0
# laestab                                        9387022.0
# urn                                               126170
# school_type                                      Special
# academy_type                                         NaN
# ...

# %%
for i in data.columns:
    print(data[i].unique())
# Out:
# ['Academic year']
# ['six half terms' 'five half terms']
# [201819 201718 201617 201516 201415 201314 201213 201112 201011 200910
#  200809 200708 200607]
# ['National' 'Regional' 'Local authority' 'School']
# ['E92000001']
# ['England']
# [nan 'E12000001' 'E12000002' 'E12000003' 'E12000004' 'E12000005'
#  'E12000006' 'E12000008' 'E12000009' 'E13000001' 'E13000002']
# [nan 'North East' 'North West' 'Yorkshire and the Humber' 'East Midlands'
#  'West Midlands' 'East of England' 'South East' 'South West'
#  'Inner London' 'Outer London']
# [ nan 201. 202. 203. 204. 205. 206. 207. 208. 209. 210. 211. 212. 213.
#  301. 302. 303. 304. 305. 306. 307. 308. 309. 310. 311. 312. 313. 314.
#  315. 316. 317. 318. 319. 320. 330. 331. 332. 333. 334. 335. 336. 340.
#  341. 342. 343. 344. 350. 351. 352. 353. 354. 355. 356. 357. 358. 359.
#  370. 371. 372. 373. 380. 381. 382. 383. 384. 390. 391. 392. 393. 394.
#  420. 800. 801. 802. 803. 805. 806. 807. 808. 810. 811. 812. 813. 815.
# ...

# %%
# !export SPARK_HOME=~/workspace_linux/usr/spark-3.3.1-bin-hadoop3
# !export PATH=$SPARK_HOME/bin:$PATH
# !export PYTHONPATH=$SPARK_HOME/python:$PYTHONPATH:$SPARK_HOME/python/lib/py4j-0.10.9.5-src.zip

# %%
# !echo $PYTHONPATH
# Out:
# /home/as627/workspace_linux/usr/spark-3.3.1-bin-hadoop3/python:/home/as627/workspace_linux/usr/spark-3.3.1-bin-hadoop3/python::/home/as627/workspace_linux/usr/spark-3.3.1-bin-hadoop3/python:/home/as627/workspace_linux/usr/spark-3.3.1-bin-hadoop3/python/lib/py4j-0.10.9.5-src.zip:/home/as627/workspace_linux/usr/spark-3.3.1-bin-hadoop3/python:/home/as627/workspace_linux/usr/spark-3.3.1-bin-hadoop3/python:

# %%
# !export SPARK_HOME=~/workspace_linux/usr/spark-3.3.1-bin-hadoop3
# !export PATH=$SPARK_HOME/bin:$PATH
# !export PYTHONPATH=$SPARK_HOME/python:$PYTHONPATH:$SPARK_HOME/python/lib/py4j-0.10.9.5-src.zip
from pyspark.sql import SparkSession
from pyspark.sql.functions import sum, col, desc
from pyspark.sql.types import StructType,StructField, StringType, IntegerType
from pyspark.sql.window import Window

# %%
from pyspark.sql.functions import avg

# %%
spark = SparkSession.builder.master("local") \
.appName("Word Count") \
.config("conf-key", "conf-value") \
.getOrCreate()
# Out:
# ...
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/04/05 15:52:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/04/05 15:52:07 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 23/04/05 15:52:07 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
data_spark = spark.read \
.format("csv") \
.option("inferSchema", "true") \
.option("header", "true") \
.load("data/pupil-absence-in-schools-in-england_2018-19/data/Absence_3term201819_nat_reg_la_sch.csv")

# %%
data_spark.where(col("geographic_level") == "Local authority").alias("a").groupBy(["la_name", "time_period"]).agg(sum("enrolments").alias("Total enrolment")).toPandas()
# Out:
#                    la_name  time_period  Total enrolment
# 0                Liverpool       201819           119366
# 1            Tower Hamlets       201718            72088
# 2           North Somerset       201516            50850
# 3                Wiltshire       201314           114018
# 4          Bristol City of       201112            85402
# ...                    ...          ...              ...
# 1967        Worcestershire       201112           131108
# 1968  Richmond upon Thames       201011            37238
# 1969               Hackney       200910            45124
# 1970               Salford       200910            52930
# 1971                Oldham       200809            69258
#
# [1972 rows x 3 columns]

# %%
data_spark.where(col("geographic_level") == "National").show()
# Out:
# 23/04/05 15:52:47 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# ...

# %%
data_spark.where(col("geographic_level") == "Local authority").alias("a").groupBy(["la_name", "time_period"]).agg(avg("enrolments").alias("Average enrolment")).toPandas()
# Out:
#                    la_name  time_period  Average enrolment
# 0                Liverpool       201819            29841.5
# 1            Tower Hamlets       201718            18022.0
# 2           North Somerset       201516            12712.5
# 3                Wiltshire       201314            28504.5
# 4          Bristol City of       201112            21350.5
# ...                    ...          ...                ...
# 1967        Worcestershire       201112            32777.0
# 1968  Richmond upon Thames       201011             9309.5
# 1969               Hackney       200910            11281.0
# 1970               Salford       200910            13232.5
# 1971                Oldham       200809            17314.5
#
# [1972 rows x 3 columns]

# %%
data.all_through.unique()
# Out:
# array([nan, 'All through', ' All through', 'All Through'], dtype=object)

# %%
data[(data.time_period == 201718)&(data.geographic_level=='School')].groupby(['school_type']).sum()
# Out:
# /tmp/ipykernel_1869868/3659403721.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data[(data.time_period == 201718)&(data.geographic_level=='School')].groupby(['school_type']).sum()
#                         time_period  old_la_code       estab       laestab  \
# school_type
# Special                   206962668     687172.0   7195064.0  6.878915e+09
# State-funded primary     3395519094   11895442.0  45319920.0  1.189997e+11
# State-funded secondary    686446354    2304823.0  15567264.0  2.306380e+10
#
#                         num_schools  enrolments  sess_possible  sess_overall  \
# school_type
# Special                        1026       99547       34515129       3527703
# State-funded primary          16833     3968042     1413955983      58989873
# ...

# %%
data.columns
# Out:
# Index(['time_identifier', 'year_breakdown', 'time_period', 'geographic_level',
#        'country_code', 'country_name', 'region_code', 'region_name',
#        'old_la_code', 'new_la_code', 'la_name', 'estab', 'laestab', 'urn',
#        'school_type', 'academy_type', 'academy_open_date', 'all_through',
#        'num_schools', 'enrolments', 'sess_possible', 'sess_overall',
#        'sess_authorised', 'sess_unauthorised', 'sess_overall_percent',
#        'sess_authorised_percent', 'sess_unauthorised_percent',
#        'enrolments_pa_10_exact', 'enrolments_pa_10_exact_percent',
#        'sess_possible_pa_10_exact', 'sess_overall_pa_10_exact',
#        'sess_authorised_pa_10_exact', 'sess_unauthorised_pa_10_exact',
#        'sess_overall_percent_pa_10_exact',
#        'sess_authorised_percent_pa_10_exact',
#        'sess_unauthorised_percent_pa_10_exact', 'sess_auth_illness',
#        'sess_auth_appointments', 'sess_auth_religious', 'sess_auth_study',
# ...

# %%
x = data[(data.geographic_level=='School')].groupby(['time_period']).sum().loc[:, "sess_auth_illness":"sess_auth_other"].T

x.nlargest(3, x.columns[0])

#.idxmax(axis=0)
#                                                                            [
# "sess_auth_appointments",
# "sess_auth_excluded",
# "sess_auth_ext_holiday",
# "sess_auth_holiday",
# "sess_auth_illness",                     
# "sess_auth_other",                
# "sess_auth_religious",                   
# "sess_auth_study",                       
# "sess_auth_totalreasons",
# "sess_auth_traveller"]]
# Out:
# /tmp/ipykernel_1869868/1997376996.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   x = data[(data.geographic_level=='School')].groupby(['time_period']).sum().loc[:, "sess_auth_illness":"sess_auth_other"].T
# time_period          200607    200708    200809    200910    201011    201112  \
# sess_auth_illness  67366501  64716707  67465292  65909856  63646885  57736947
# sess_auth_holiday  11801135  10390395   9371520   7790997   7087759   6554732
# sess_auth_other    10558039   8178925   8512283   9364329   6734198   5852743
#
# time_period          201213    201314    201415    201516    201617    201718  \
# sess_auth_illness  69691693  59982833  65207611  62335171  62280633  63987585
# sess_auth_holiday   8264912   2668317   1733647   1707882   1805876   1696409
# ...

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import rank, col

window = Window.partitionBy(data_spark['time_period'])

# df.select('*', rank().over(window).alias('rank')) 
#   .filter(col('rank') <= 2) 
#   .show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 window.show()
#
# AttributeError: 'WindowSpec' object has no attribute 'show'

# %%
x.columns[0]
# Out:
# 200607

# %%
data[(data.time_period == 201718) & (~data.all_through.isnull())].groupby(['school_type']).sum()

# %%
data['region_code'].unique()
# Out:
# array([nan, 'E12000001', 'E12000002', 'E12000003', 'E12000004',
#        'E12000005', 'E12000006', 'E12000008', 'E12000009', 'E13000001',
#        'E13000002'], dtype=object)

# %%
data_spark.where(col("geographic_level") == "Local authority")
# Out:
# DataFrame[time_identifier: string, year_breakdown: string, time_period: int, geographic_level: string, country_code: string, country_name: string, region_code: string, region_name: string, old_la_code: int, new_la_code: string, la_name: string, estab: int, laestab: int, urn: string, school_type: string, academy_type: string, academy_open_date: string, all_through: string, num_schools: int, enrolments: int, sess_possible: bigint, sess_overall: int, sess_authorised: int, sess_unauthorised: int, sess_overall_percent: double, sess_authorised_percent: double, sess_unauthorised_percent: double, enrolments_pa_10_exact: int, enrolments_pa_10_exact_percent: double, sess_possible_pa_10_exact: int, sess_overall_pa_10_exact: int, sess_authorised_pa_10_exact: int, sess_unauthorised_pa_10_exact: int, sess_overall_percent_pa_10_exact: double, sess_authorised_percent_pa_10_exact: double, sess_unauthorised_percent_pa_10_exact: double, sess_auth_illness: int, sess_auth_appointments: int, sess_auth_rel
# ...

# %% [markdown]
# ### Part 1

# %% [markdown]
# #### Allow the user to search the dataset by the local authority, showing the number of pupil enrolments in each local authority by time period (year).
# – Given a list of local authorities, display in a well-formatted fashion
# the number of pupil enrolments in each local authority by time period
# (year).

# %%
def get_enrolment(data, local_authorities: list):
    # w = Window.rowsBetween(Window.unboundedPreceding, Window.unboundedFollowing)
    # data.withColumn('dummy_column', f.max('date').over(w).cast('timestamp')).show(9)
    # ret = data.select(sum("enrolments")) \
    ret = data.where(col("la_name").isin(local_authorities)) \
.groupBy(["la_name", "time_period"]) \
.agg(sum("enrolments").alias("Total enrolments")) \
.orderBy(["la_name", "time_period"])
    ret.show(10000, truncate=False)
    return ret.toPandas()

# %%
x = get_enrolment(data_spark, ['Birmingham', 'Coventry', 'Dudley', 'Sandwell','Solihull', 'Walsall', 'Wolverhampton'])
# Out:
# +-------------+-----------+----------------+
# |la_name      |time_period|Total enrolments|
# +-------------+-----------+----------------+
# |Birmingham   |200607     |467211          |
# |Birmingham   |200708     |462099          |
# |Birmingham   |200809     |460509          |
# |Birmingham   |200910     |461382          |
# |Birmingham   |201011     |461835          |
# |Birmingham   |201112     |464865          |
# |Birmingham   |201213     |470160          |
# |Birmingham   |201314     |475830          |
# |Birmingham   |201415     |491670          |
# |Birmingham   |201516     |501444          |
# |Birmingham   |201617     |518679          |
# |Birmingham   |201718     |524814          |
# |Birmingham   |201819     |536280          |
# |Coventry     |200607     |124062          |
# |Coventry     |200708     |122859          |
# |Coventry     |200809     |122892          |
# |Coventry     |200910     |123624          |
# |Coventry     |201011     |123237          |
# ...

# %%
x
# Out:
#           la_name  time_period  Total enrolments
# 0      Birmingham       200607            467211
# 1      Birmingham       200708            462099
# 2      Birmingham       200809            460509
# 3      Birmingham       200910            461382
# 4      Birmingham       201011            461835
# ..            ...          ...               ...
# 86  Wolverhampton       201415             97542
# 87  Wolverhampton       201516            102102
# 88  Wolverhampton       201617            109596
# 89  Wolverhampton       201718            111546
# 90  Wolverhampton       201819            114654
#
# [91 rows x 3 columns]

# %%
def get_enrolments(la: list):
    return data[data["la_name"].isin(la)].loc[:,['la_name', 'time_period', 'enrolments']].groupby(['la_name', 'time_period']).sum()

# %%
get_enrolments(['Birmingham', 'Coventry', 'Dudley', 'Sandwell',
       'Solihull', 'Walsall', 'Wolverhampton'])

# %%
data[data["la_name"].isin(['Islington'])]

# %% [markdown]
# #### Allow the user to search the dataset by school type, showing the total number of pupils who were given authorised absences because of medical appointments or illness in the time period 2017-2018.

# %%
data['school_type'].unique()
# Out:
# array(['Total', 'State-funded primary', 'State-funded secondary',
#        'Special'], dtype=object)

# %%
data_spark.filter(col('time_period') == 201718)\
          .filter(col('school_type') == 'State-funded secondary') \
        .select(["la_name","sess_auth_appointments", "sess_auth_illness"]).orderBy(["la_name"]).show()
# Out:
# +--------------------+----------------------+-----------------+
# |             la_name|sess_auth_appointments|sess_auth_illness|
# +--------------------+----------------------+-----------------+
# |                null|               3379057|         29018679|
# |                null|                137791|          1384815|
# |                null|                358292|          2584684|
# |                null|                340666|          3286490|
# |                null|                429450|          3929174|
# |                null|                399720|          3419712|
# |                null|                570439|          4795557|
# |                null|                293671|          2688915|
# |                null|                373161|          3207134|
# |                null|                176559|          1228809|
# |                null|                299308|          2493389|
# |Barking and Dagenham|                  1530|             8471|
# ...

# %% [markdown]
# #### Allow a user to search for all unauthorised absences in a certain year, broken down by either region name or local authority name.

# %%
year = 201718

# %%
# region_name or la_name
data_spark.filter(col("time_period") == year).groupBy(["la_name", "time_period"]) \
.agg(sum("sess_unauthorised").alias("Number of unauthorised absence sessions")).orderBy(["la_name", "time_period"]).show(1000)
# Out:
# +--------------------+-----------+---------------------------------------+
# |             la_name|time_period|Number of unauthorised absence sessions|
# +--------------------+-----------+---------------------------------------+
# |                null|     201718|                              133713108|
# |Barking and Dagenham|     201718|                                 628941|
# |              Barnet|     201718|                                 431088|
# |            Barnsley|     201718|                                 654435|
# |Bath and North Ea...|     201718|                                 255192|
# |             Bedford|     201718|                                 308766|
# |              Bexley|     201718|                                 472941|
# |          Birmingham|     201718|                                3123708|
# |Blackburn with Da...|     201718|                                 323895|
# ...

# %% [markdown]
# #### List the top 3 reasons for authorised absences in each year.

# %%
data_spark.where(col("geographic_level") == "Regional").where(col("time_period") == 201617).groupBy("region_name").agg(
     sum("sess_unauthorised").alias("All unauthorised absences"),
    #  sum("sess_unauth_holiday").alias("Holidays"),
).toPandas()
# Out:
#                 region_name  All unauthorised absences
# 0                North West                    9057036
# 1                South East                    8558670
# 2              Inner London                    3375532
# 3           East of England                    6019372
# 4              Outer London                    5769436
# 5                South West                    4945336
# 6             East Midlands                    5272010
# 7             West Midlands                    7113912
# 8  Yorkshire and the Humber                    7804312
# 9                North East                    3443988

# %%
t = data_spark.where(col("geographic_level") == "National").groupBy('time_period').agg(
    sum("sess_auth_appointments").alias("appointments"),
    sum("sess_auth_excluded").alias("excluded"),
    sum("sess_auth_ext_holiday").alias("extended_holiday"),
    sum("sess_auth_holiday").alias("holiday"),
    sum("sess_auth_illness").alias("illness"),
    sum("sess_auth_other").alias("other"),
    sum("sess_auth_religious").alias("religious"),
    sum("sess_auth_study").alias("study"),
    sum("sess_auth_traveller").alias("travel")
).orderBy(col("time_period"))

# %%
filtered_data = data_spark.where(col('school_type') == 'Special')\
                        .where(col('time_period') == 201718)\
        .groupBy(["school_type", "time_period"])\
        .agg(
            sum("sess_auth_illness").alias("Illness"),
            sum("sess_auth_appointments").alias("Appointments"),
            ).toPandas()
        # .join(data.alias("b").select("la_name", "new_la_code", "time_period"), col("a.la_name") == col("b.la_name"), "left")\
        # .select(col("b.time_period").alias("Year"), col("b.new_la_code"), col("a.la_name"), col("Total enrolment"))\
        # .distinct()\
        # .orderBy(col("b.time_period"))\
        # .toPandas()

# %%
filtered_data.melt(value_vars=['Illness', 'Appointments'])
# Out:
#        variable    value
# 0       Illness  6013552
# 1  Appointments  1495644

# %%
t.show()
# Out:
# [Stage 3:>                                                          (0 + 1) / 1]
# +-----------+------------+--------+----------------+--------+---------+--------+---------+-------+------+
# |time_period|appointments|excluded|extended_holiday| holiday|  illness|   other|religious|  study|travel|
# +-----------+------------+--------+----------------+--------+---------+--------+---------+-------+------+
# |     200607|    16252430| 4957538|        853080.0|23602270|134733002|21116078|   220224|5060498|714246|
# |     200708|    13196390| 3477322|        626170.0|20780790|129433414|16357850|  2505880|3420134|599746|
# |     200809|    13130392| 3465194|        504734.0|18743040|134930584|17024566|  3914966|2518758|545922|
# |     200910|    12912732| 3104876|        486116.0|15581994|131819712|18728658|  2356648|2440754|522108|
# |     201011|    12655800| 2962556|        347640.0|14175518|127293770|13468396|  3400704|2152702|546450|
# ...

# %%
[sum("sess_auth_appointments"),
sum("sess_auth_excluded"),
sum("sess_auth_ext_holiday"),
sum("sess_auth_holiday"),
sum("sess_auth_illness"),
sum("sess_auth_other"),
("sess_auth_religious"),
sum("sess_auth_study"),
sum("sess_auth_totalreasons"),
sum("sess_auth_traveller")]

# %% [markdown]
# ## Part 2

# %% [markdown]
# #### Allow a user to compare two local authorities of their choosing in a given year.
# Justify how you will compare and present the data.

# %% [markdown]
# #### Chart/explore the performance of regions in England from 2006-2018.
# Your charts and subsequent analysis in your report should answer the
# following questions:
# - Are there any regions that have improved in pupil attendance over the years?
# - Are there any regions that have worsened?
# - Which is the overall best/worst region for pupil attendance?

# %% [markdown]
# ## Part 3
#
# In order to obtain a grade greater than 16.5, you must implement some more advanced features. Part 3 should build on the functionality provided by Part 2 and provide interesting reports and/or insights into the dataset. Interesting can be interpreted any way you see fit but should include some form of advanced analysis (for example, using predictions). Some suggestions are below:
# - Visualisation and interaction of the dataset, using external libraries.
# - Analyse whether there is a link between school type, pupil absences and the location of the school. For example, is it more likely that schools of type X will have more pupil absences in location Y?
# - Provide school recommendations using machine learning for parents looking for a new school for their child in 2023. Based on past data, can you predict which part of the country will provide schools with the best pupil attendance?
# - Any other advanced feature of your choosing
